# %%
from pymongo import MongoClient

# Set up the MongoDB Atlas URI
MONGODB_ATLAS_URI = "mongodb+srv://exmample:1234567890AB@cluster0.nerjmcv.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Connect to the MongoDB Atlas cluster
client = MongoClient(MONGODB_ATLAS_URI)

# Access the test_db database
db = client['test_db']

def print_n_col1_records(N):
    col1_records = db.col1.find().limit(N)
    print("Перші", N, "записів колекції №1:")
    for record in col1_records:
        print(record)

def print_m_col2_records(M):
    col2_records = db.col2.find().limit(M)
    print("Перші", M, "записів колекції №2:")
    for record in col2_records:
        print(record)

def document_chains(start_index, MAXK):
    print("Ланцюжки документів з колекцій №1 і №2, починаючи з елемента", start_index, "колекції №1:")
    col1_record = db.col1.find_one({"_id": start_index})
    count = 0
    while col1_record and count < MAXK:
        print(col1_record)
        friend_id = col1_record.get("friend")
        if friend_id is None:
            break
        col2_record = db.col2.find_one({"_id": friend_id})
        if col2_record:
            print(col2_record)
            friend_id = col2_record.get("friend")
            if friend_id is None:
                break
            col1_record = db.col1.find_one({"_id": friend_id})
        else:
            break
        count += 1

# Виведення перших N записів колекції N1
#print_n_col1_records(11)

# Виведення перших M записів колекції N2
#print_m_col2_records(11)

# Виведення ланцюжків документів
document_chains(1, 11)

# Close the MongoDB client
client.close()
# Out:
# Перші 11 записів колекції №1:
# {'_id': 1, 'name': 'Name_1', 'friend': 846}
# {'_id': 4, 'name': 'Name_4', 'friend': 334}
# {'_id': 9, 'name': 'Name_9', 'friend': 717}
# {'_id': 17, 'name': 'Name_17', 'friend': 628}
# {'_id': 18, 'name': 'Name_18', 'friend': 767}
# {'_id': 19, 'name': 'Name_19', 'friend': 403}
# {'_id': 21, 'name': 'Name_21', 'friend': 869}
# {'_id': 22, 'name': 'Name_22', 'friend': 79}
# {'_id': 23, 'name': 'Name_23', 'friend': 224}
# {'_id': 24, 'name': 'Name_24', 'friend': 564}
# {'_id': 25, 'name': 'Name_25', 'friend': 159}
# Перші 11 записів колекції №2:
# {'_id': 2, 'name': 'Name_2', 'friend': 797}
# {'_id': 11, 'name': 'Name_11', 'friend': 369}
# {'_id': 12, 'name': 'Name_12', 'friend': 659}
# {'_id': 14, 'name': 'Name_14', 'friend': 656}
# {'_id': 16, 'name': 'Name_16', 'friend': 671}
# {'_id': 20, 'name': 'Name_20', 'friend': 562}
# {'_id': 26, 'name': 'Name_26', 'friend': 466}
# {'_id': 30, 'name': 'Name_30', 'friend': 417}
# ...
